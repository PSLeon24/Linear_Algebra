# %% [markdown]
# # Chap 1의 연습 문제
# - 정답: https://github.com/Sancho-kim/LinAlg4DS

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 연습 문제 1-1
# - 예제 코드에 '누락된' 부분을 찾고 이를 올바른 코드로 고치기
# ![%E1%84%8B%E1%85%B5%E1%84%8F%E1%85%A9%E1%84%90%E1%85%A6%20-%200%204.jpg](attachment:%E1%84%8B%E1%85%B5%E1%84%8F%E1%85%A9%E1%84%90%E1%85%A6%20-%200%204.jpg)

# %% [markdown]
# ## 연습 문제 1-2
# - 아래 식을 코드로 변환해서 벡터 노름을 계산하는 알고리즘을 작성하자.
# - ||v|| = √(∑vi^2)
# - 차원과 방향이 다른 난수 벡터를 사용해서 np.linalg.norm()과 동일한 결과를 얻는지 확인해보자.

# %% [markdown]
# ## 연습 문제 1-3
# - 벡터를 입력으로 받아 동일한 방향의 단위벡터를 출력하는 파이썬 함수를 구현해보자.

# %% [markdown]
# ## 연습 문제 1-4
# - 벡터와 원하는 크기를 입력 받고 벡터와 동일한 방향이지만 두 번째 입력에 해당하는 크기를 가진 벡터를 반환하는 파이썬 함수를 구현해보자.

# %% [markdown]
# ## 연습 문제 1-5
# - np.transpose(v) 또는 v.T와 같은 내장 함수 또는 메서드를 사용하지 않고 행벡터를 열벡터로 전치하는 for 루프를 작성해보자.

# %% [markdown]
# ## 연습 문제 1-6
# - 벡터의 제곱 노름을 그 벡터 자체의 내적으로 계산할 수 있음. 이를 파이썬으로 구현해보자.

# %% [markdown]
# ## 연습 문제 1-7
# - 내적의 교환 법칙을 입증하는 코드를 작성
# - 교환 법칙은 a x b = b x a를 의미하며, 벡터의 내적에서는 aᵀb=bᵀa를 의미함
# - 코드를 구현하고 'a·b = ∑ab' 식을 사용해 내적이 교환 가능한 이유를 설명해보자.

# %% [markdown]
# ## 연습 문제 1-8
# - 아래 그림을 코드로 구현하자.(단, 핵심 원소만 존재한다면 답은 그림과 완벽히 똑같지 않아도 됨)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 연습 문제 1-9
# - 직교벡터 분해를 구현하자.
# - 두 난수 벡터 t와 r로 시작해서 아래 그림을 재현하자.(난수로 인해 완벽히 똑같지 않을 수 있음)
# ![%E1%84%8B%E1%85%B5%E1%84%8F%E1%85%A9%E1%84%90%E1%85%A6%20-%200%202.jpg](attachment:%E1%84%8B%E1%85%B5%E1%84%8F%E1%85%A9%E1%84%90%E1%85%A6%20-%200%202.jpg)
# - 그리고 두 성분의 합이 t이고, t⊥r과 t||r이 직교하는지 확인하자

# %% [markdown]
# ## 연습 문제 1-10
# - 코딩에서 버그를 찾아내는 기술은 매우 중요
# - 코드 버그로 인해 의 투영 스칼라의 분모가 rᵀr이 아닌 tᵀt가 되었다고 가정해 보자.
# - 이 버그를 구현해서 정확한 코드와 얼마나 차이가 있는지 확인해 보자.
# - 온전성 검사: 코딩에서 알려진 결과를 통해 코드를 점검하는 것
